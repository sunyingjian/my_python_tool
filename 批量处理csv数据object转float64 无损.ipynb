# %%
import pandas as pd

# %%
import glob
path = r'20200926'
allFiles = glob.glob(path + "/*.csv")

# %%
for file_ in allFiles:
    df = pd.read_csv(file_,sep=',')

# %%
df
# Out:
#       Unnamed: 0  \
# 0              0
# 1              1
# 2              2
# 3              3
# 4              4
# ...          ...
# 7079        7079
# 7080        7080
# 7081        7081
# 7082        7082
# 7083        7083
#
#      WELL,DEPTH_MD,X_LOC,Y_LOC,Z_LOC,GROUP,FORMATION,CALI,RSHA,RMED,RDEP,RHOB,GR,NPHI,PEF,DTC,SP,BS,ROP,DRHO,FORCE_2020_LITHOFACIES_LITHOLOGY,FORCE_2020_LITHOFACIES_CONFIDENCE
# 0     34/8-7 R,4360.016,476274.375,6798590,-4333.147...
# 1     34/8-7 R,4360.168,476274.375,6798590,-4333.298...
# 2     34/8-7 R,4360.32,476274.375,6798590,-4333.4501...
# 3     34/8-7 R,4360.472,476274.3438,6798590,-4333.60...
# 4     34/8-7 R,4360.624,476274.3438,6798590,-4333.75...
# ...                                                 ...
# 7079  34/8-7 R,5436.024,476401.5,6798676,-5394.96728...
# 7080  34/8-7 R,5436.176,476401.5313,6798676,-5395.11...
# 7081  34/8-7 R,5436.328,476401.5625,6798676,-5395.26...
# 7082  34/8-7 R,5436.48,476401.5938,6798676,-5395.414...
# ...

# %%
import chardet

# %%
path = '20200926/25-2-13 T4.csv'
f = open(path,'rb')
data = f.read()
print(chardet.detect(data))
# Out:
# {'encoding': 'ascii', 'confidence': 1.0, 'language': ''}

# %%
import pandas as pd

# %%
data = pd.read_csv(path)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21062 entries, 0 to 21061
# Data columns (total 22 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   WELL                               21062 non-null  object
#  1   DEPTH_MD                           21062 non-null  float64
#  2   X_LOC                              21062 non-null  float64
#  3   Y_LOC                              21062 non-null  float64
#  4   Z_LOC                              21062 non-null  float64
#  5   GROUP                              21062 non-null  object
#  6   FORMATION                          21062 non-null  object
#  7   CALI                               21062 non-null  float64
#  8   RSHA                               21062 non-null  float64
#  9   RMED                               21062 non-null  float64
#  10  RDEP                               21062 non-null  float64
# ...

# %%
data
# Out:
#              WELL  DEPTH_MD        X_LOC      Y_LOC        Z_LOC  \
# 0      25/2-13 T4   694.808  469334.6250  6628720.0  -672.621521
# 1      25/2-13 T4   694.960  469334.6250  6628720.0  -672.773376
# 2      25/2-13 T4   695.112  469334.6250  6628720.0  -672.925293
# 3      25/2-13 T4   695.264  469334.6250  6628720.0  -673.077148
# 4      25/2-13 T4   695.416  469334.6250  6628720.0  -673.229004
# ...           ...       ...          ...        ...          ...
# 21057  25/2-13 T4  3895.472  469384.9688  6628683.5 -3868.723389
# 21058  25/2-13 T4  3895.624  469385.0000  6628683.5 -3868.875244
# 21059  25/2-13 T4  3895.776  469385.0000  6628683.5 -3869.026855
# 21060  25/2-13 T4  3895.928  469385.0000  6628683.5 -3869.178223
# 21061  25/2-13 T4  3896.080  469385.0000  6628683.5 -3869.329834
#
#               GROUP       FORMATION       CALI      RSHA      RMED  ...  \
# 0      NORDLAND GP.      Utsira Fm.  18.813000  0.436556  0.428556  ...
# ...

# %%
datanew = data.drop(['WELL','GROUP','FORMATION','FORCE_2020_LITHOFACIES_LITHOLOGY','FORCE_2020_LITHOFACIES_CONFIDENCE'],axis=1)

# %%
datanew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21062 entries, 0 to 21061
# Data columns (total 17 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   DEPTH_MD  21062 non-null  float64
#  1   X_LOC     21062 non-null  float64
#  2   Y_LOC     21062 non-null  float64
#  3   Z_LOC     21062 non-null  float64
#  4   CALI      21062 non-null  float64
#  5   RSHA      21062 non-null  float64
#  6   RMED      21062 non-null  float64
#  7   RDEP      21062 non-null  float64
#  8   RHOB      21062 non-null  float64
#  9   GR        21062 non-null  float64
#  10  NPHI      21062 non-null  float64
#  11  PEF       21062 non-null  float64
#  12  DTC       21062 non-null  float64
#  13  SP        21062 non-null  float64
#  14  BS        21062 non-null  float64
#  15  ROP       21062 non-null  object
#  16  DRHO      21062 non-null  float64
# dtypes: float64(16), object(1)
# memory usage: 2.7+ MB

# %%
import numpy as np

# %%
col = list(datanew.columns)
datanew[col] = datanew[col].apply(pd.to_numeric, errors='coerce').fillna(0.0)
datanew = pd.DataFrame(datanew, dtype='float')

# %%
datanew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21062 entries, 0 to 21061
# Data columns (total 17 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   DEPTH_MD  21062 non-null  float64
#  1   X_LOC     21062 non-null  float64
#  2   Y_LOC     21062 non-null  float64
#  3   Z_LOC     21062 non-null  float64
#  4   CALI      21062 non-null  float64
#  5   RSHA      21062 non-null  float64
#  6   RMED      21062 non-null  float64
#  7   RDEP      21062 non-null  float64
#  8   RHOB      21062 non-null  float64
#  9   GR        21062 non-null  float64
#  10  NPHI      21062 non-null  float64
#  11  PEF       21062 non-null  float64
#  12  DTC       21062 non-null  float64
#  13  SP        21062 non-null  float64
#  14  BS        21062 non-null  float64
#  15  ROP       21062 non-null  float64
#  16  DRHO      21062 non-null  float64
# dtypes: float64(17)
# memory usage: 2.7 MB
